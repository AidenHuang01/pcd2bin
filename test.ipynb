# %%
from os import listdir
from os.path import isfile, join
mypath = '/home/yucheng/storage/data/test04_17_wild6/mtlb-pcdFromBag'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
for pcd in listdir(mypath):
    print(pcd[-4:])
# Out:
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .cam
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
# .pcd
